# %%
import sys
sys.path.append('../')

import fomspace

grating_name = "opt_grating"
npoints = 100
pkl_fname = f"./Data/{grating_name}_fomspace_pitch_by_depth_npoints{npoints}.pkl"

fig, ax = fomspace.show_FOM_space(pkl_fname)
fig.savefig(f"./Data/{grating_name}_fomspace.pdf")
