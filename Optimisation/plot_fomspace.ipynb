# %%
import sys
sys.path.append('../')

import fomspace

grating_name = "standard_grating"
npoints = 2
pkl_fname = f"./Data/{grating_name}_fomspace_pitch_by_depth_npoints{npoints}.pkl"

fig, ax = fomspace.show_FOM_space(pkl_fname)
# fig.savefig(f"{grating_name}_fomspace.pdf")
# Out:
# -9.654176677686204
# -9.654176677686204
