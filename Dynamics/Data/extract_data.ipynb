# %%
import pickle

save_fname = "./jacobian_coefficients.pkl"
with open(save_fname, 'rb') as data_file:
    jacobian_coefficients = pickle.load(data_file)
print(jacobian_coefficients.shape)

# Ordering:
# dimension 1:  (kyy,   kyphi,   muyy,   muyphi)
# dimension 2:  (kphiy, kphiphi, muphiy, muphiphi)
# dimension 3:  coefficients at every wavelength from v = 0 to v = 0.2c
# E.g. jacobian_coefficients[0, 2, :]  # muyy coefficients at every wavelength
# E.g. jacobian_coefficients[1, 1, :]  # kphiphi coefficients at every wavelength
# Out:
# (2, 4, 1000)
